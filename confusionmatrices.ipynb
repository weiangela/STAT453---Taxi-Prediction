# %%
import matplotlib.pyplot as plt
import numpy as np


confusion_matrix = np.array([[229448, 1309, 5, 0],
                              [3012, 394869, 3099, 0],
                              [2, 14415, 36361, 14],
                              [0, 0, 81, 324]])

plt.figure(figsize=(8, 6))
plt.imshow(confusion_matrix, interpolation='nearest')
plt.title('Model 1')
plt.colorbar()

classes = ['[0%,10%]', '[10%,20%]', '[20%,50%]', '[50%,100%]']
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

thresh = confusion_matrix.max() / 2.
for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        plt.text(j, i, format(confusion_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if confusion_matrix[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
confusion_matrix = np.array([[229307,  1450,      5,      0],
                              [  2792, 393778,  4410,     0],
 [     2,  13616,  37155,     19],
 [     0,      0,     22,    383]])


plt.figure(figsize=(8, 6))
plt.imshow(confusion_matrix, interpolation='nearest')
plt.title('Model 2')
plt.colorbar()


classes = ['[0%,10%]', '[10%,20%]', '[20%,50%]', '[50%,100%]']
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

thresh = confusion_matrix.max() / 2.
for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        plt.text(j, i, format(confusion_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if confusion_matrix[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
confusion_matrix = np.array([[229447,   1310,      5,      0],
 [  3013, 394868,   3099,      0],
 [     2,  14417,  36360,     13],
 [     0,      0,     82,    323]])


plt.figure(figsize=(8, 6))
plt.imshow(confusion_matrix, interpolation='nearest')
plt.title('Model 3')
plt.colorbar()


classes = ['[0%,10%]', '[10%,20%]', '[20%,50%]', '[50%,100%]']
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

thresh = confusion_matrix.max() / 2.
for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        plt.text(j, i, format(confusion_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if confusion_matrix[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
confusion_matrix = np.array([[229485,   1272,      5,      0],
 [  3084, 395369,   2527,      0],
 [     2,  14806,  35973,     11],
 [     0,      0,    119,    286]])


plt.figure(figsize=(8, 6))
plt.imshow(confusion_matrix, interpolation='nearest')
plt.title('Model 4')
plt.colorbar()


classes = ['[0%,10%]', '[10%,20%]', '[20%,50%]', '[50%,100%]']
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

thresh = confusion_matrix.max() / 2.
for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        plt.text(j, i, format(confusion_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if confusion_matrix[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
confusion_matrix = np.array([[229512,   1245,      5,      0],
 [  3124, 395781,   2075,      0],
 [     2,  15135,  35642,     13],
 [     0,      0,    141,    264]])

plt.figure(figsize=(8, 6))
plt.imshow(confusion_matrix, interpolation='nearest')
plt.title('Model 5')
plt.colorbar()


classes = ['[0%,10%]', '[10%,20%]', '[20%,50%]', '[50%,100%]']
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)


thresh = confusion_matrix.max() / 2.
for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        plt.text(j, i, format(confusion_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if confusion_matrix[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
